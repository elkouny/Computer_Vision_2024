# %% [markdown]
# # Coursework 2: Image segmentation
#
# In this coursework you will develop and train a convolutional neural network for brain tumour image segmentation. Please read both the text and the code in this notebook to get an idea what you are expected to implement. Pay attention to the missing code blocks that look like this:
#
# ```
# ### Insert your code ###
# ...
# ### End of your code ###
# ```
#
# ## What to do?
#
# * Complete and run the code using `jupyter-lab` or `jupyter-notebook` to get the results.
#
# * Export (File | Save and Export Notebook As...) the notebook as a PDF file, which contains your code, results and answers, and upload the PDF file onto [Scientia](https://scientia.doc.ic.ac.uk).
#
# * Instead of clicking the Export button, you can also run the following command instead: `jupyter nbconvert coursework.ipynb --to pdf`
#
# * If Jupyter complains about some problems in exporting, it is likely that pandoc (https://pandoc.org/installing.html) or latex is not installed, or their paths have not been included. You can install the relevant libraries and retry.
#
# * If Jupyter-lab does not work for you at the end, you can use Google Colab to write the code and export the PDF file.
#
# ## Dependencies
#
# You need to install Jupyter-Lab (https://jupyterlab.readthedocs.io/en/stable/getting_started/installation.html) and other libraries used in this coursework, such as by running the command:
# `pip3 install [package_name]`
#
# ## GPU resource
#
# The coursework is developed to be able to run on CPU, as all images have been pre-processed to be 2D and of a smaller size, compared to original 3D volumes.
#
# However, to save training time, you may want to use GPU. In that case, you can run this notebook on Google Colab. On Google Colab, go to the menu, Runtime - Change runtime type, and select **GPU** as the hardware acceleartor. At the end, please still export everything and submit as a PDF file on Scientia.

# %%
# Import libraries
# These libraries should be sufficient for this tutorial.
# However, if any other library is needed, please install by yourself.
import tarfile
import imageio
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
import numpy as np
import time
import os
import random
import matplotlib.pyplot as plt
from matplotlib import colors
np.random.seed(500)

# %% [markdown]
# ## 1. Download and visualise the imaging dataset.
#
# The dataset is curated from the brain imaging dataset in [Medical Decathlon Challenge](http://medicaldecathlon.com/). To save the storage and reduce the computational cost for this tutorial, we extract 2D image slices from T1-Gd contrast enhanced 3D brain volumes and downsample the images.
#
# The dataset consists of a training set and a test set. Each image is of dimension 120 x 120, with a corresponding label map of the same dimension. There are four number of classes in the label map:
#
# - 0: background
# - 1: edema
# - 2: non-enhancing tumour
# - 3: enhancing tumour

# %%
# # Download the dataset
# !wget https://www.dropbox.com/s/zmytk2yu284af6t/Task01_BrainTumour_2D.tar.gz

# # Unzip the '.tar.gz' file to the current directory
# datafile = tarfile.open('Task01_BrainTumour_2D.tar.gz')
# datafile.extractall()
# datafile.close()

# %% [markdown]
# ## Visualise a random set of 4 training images along with their label maps.
#
# Suggested colour map for brain MR image:
# ```
# cmap = 'gray'
# ```
#
# Suggested colour map for segmentation map:
# ```
# cmap = colors.ListedColormap(['black', 'green', 'blue', 'red'])
# ```

# %%
### Insert your code ###
image_names = os.listdir("Task01_BrainTumour_2D/training_images")
image_chosen = random.sample(image_names,4)
for label in image_chosen:
    print(f'image : {label} label : {label}')
    plt.subplot(1, 2, 1)
    plt.imshow(imageio.imread(f'Task01_BrainTumour_2D/training_images/{label}'),cmap='grey')
    plt.title('Training Image')
    # Load and display the corresponding label image
    plt.subplot(1, 2, 2)
    plt.imshow(imageio.imread(f'Task01_BrainTumour_2D/training_labels/{label}'),cmap = colors.ListedColormap(['black', 'green', 'blue', 'red']))
    plt.title('Training Label')
    # Adjust the figure size
    plt.gcf().set_size_inches(8, 4)
    # Show the plot
    plt.show()
### End of your code ###
# Out:
# image : BRATS_057_z46.png label : BRATS_057_z46.png
# /var/folders/ry/ywyvjwq15kz7n3wt6jvsf6sc0000gn/T/ipykernel_51807/3141242617.py:7: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imageio.imread(f'Task01_BrainTumour_2D/training_images/{label}'),cmap='grey')
# /var/folders/ry/ywyvjwq15kz7n3wt6jvsf6sc0000gn/T/ipykernel_51807/3141242617.py:11: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   plt.imshow(imageio.imread(f'Task01_BrainTumour_2D/training_labels/{label}'),cmap = colors.ListedColormap(['black', 'green', 'blue', 'red']))
# image : BRATS_400_z46.png label : BRATS_400_z46.png
# image : BRATS_285_z124.png label : BRATS_285_z124.png
# image : BRATS_478_z93.png label : BRATS_478_z93.png

# %% [markdown]
# ## 2. Implement a dataset class.
#
# It can read the imaging dataset and get items, pairs of images and label maps, as training batches.

# %%
def normalise_intensity(image, thres_roi=1.0):
    """ Normalise the image intensity by the mean and standard deviation """
    # ROI defines the image foreground
    val_l = np.percentile(image, thres_roi)
    roi = (image >= val_l)
    mu, sigma = np.mean(image[roi]), np.std(image[roi])
    eps = 1e-6
    image2 = (image - mu) / (sigma + eps)
    return image2


class BrainImageSet(Dataset):
    """ Brain image set """
    def __init__(self, image_path, label_path='', deploy=False):
        self.image_path = image_path
        self.deploy = deploy
        self.images = []
        self.labels = []

        image_names = sorted(os.listdir(image_path))
        for image_name in image_names:
            # Read the image
            image = imageio.imread(os.path.join(image_path, image_name))
            self.images += [image]

            # Read the label map
            if not self.deploy:
                label_name = os.path.join(label_path, image_name)
                label = imageio.imread(label_name)
                self.labels += [label]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        # Get an image and perform intensity normalisation
        # Dimension: XY
        image = normalise_intensity(self.images[idx])

        # Get its label map
        # Dimension: XY
        label = self.labels[idx]
        return image, label

    def get_random_batch(self, batch_size):
        # Get a batch of paired images and label maps
        # Dimension of images: NCXY
        # Dimension of labels: NXY
        # N = batch size C = channels X,Y = dimensions
        images, labels = [], []

        ### Insert your code ###
        indexes = random.sample(range(len(self.images)),batch_size)
        
        for index in indexes:
            image,label = self.__getitem__(index)
            images.append(image)
            labels.append(label)
        
        ### End of your code ###
        images = np.array(images)
        labels = np.array(labels)
        new_images = np.reshape(images, (images.shape[0], 1, images.shape[1], images.shape[2]))
        return new_images, labels

# %% [markdown]
# ## 3. Build a U-net architecture.
#
# You will implement a U-net architecture. If you are not familiar with U-net, please read this paper:
#
# [1] Olaf Ronneberger et al. [U-Net: Convolutional networks for biomedical image segmentation](https://link.springer.com/chapter/10.1007/978-3-319-24574-4_28). MICCAI, 2015.
#
# For the first convolutional layer, you can start with 16 filters. We have implemented the encoder path. Please complete the decoder path.

# %%
""" U-net """
class UNet(nn.Module):
    def __init__(self, input_channel=1, output_channel=1, num_filter=16):
        super(UNet, self).__init__()

        # BatchNorm: by default during training this layer keeps running estimates
        # of its computed mean and variance, which are then used for normalization
        # during evaluation.

        # Encoder path
        n = num_filter  # 16 // 64 in paper 1st row
        self.conv1 = nn.Sequential(
            nn.Conv2d(input_channel, n, kernel_size=3, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU(),
            nn.Conv2d(n, n, kernel_size=3, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU()
        )

        n *= 2  # 32 // 128 in paper 2nd row first conv is the red blue arrow in paper
        self.conv2 = nn.Sequential(
            nn.Conv2d(int(n / 2), n, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU(),
            nn.Conv2d(n, n, kernel_size=3, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU()
        )

        n *= 2  # 64 // 256 in paper 3rd row
        self.conv3 = nn.Sequential(
            nn.Conv2d(int(n / 2), n, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU(),
            nn.Conv2d(n, n, kernel_size=3, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU()
        )

        n *= 2  # 128 // 512 in paper 4th row
        self.conv4 = nn.Sequential(
            nn.Conv2d(int(n / 2), n, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU(),
            nn.Conv2d(n, n, kernel_size=3, padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU()
        )

        # Decoder path
        ### Insert your code ###
        n=int(n/2) # 64

        self.up1 = nn.ConvTranspose2d(2*n, n, kernel_size=2, stride=2)


        self.conv5 = nn.Sequential(
            nn.Conv2d(2*n,n,kernel_size=3,padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU(),
            nn.Conv2d(n,n,kernel_size=3,padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU()
        )
        n=int(n/2) #32

        self.up2 = nn.ConvTranspose2d(2*n, n, kernel_size=2, stride=2)


        self.conv6 = nn.Sequential(
            nn.Conv2d(2*n,n,kernel_size=3,padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU(),
            nn.Conv2d(n,n,kernel_size=3,padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU()
        )
        n=int(n/2) #128 in paper
        self.up3 =  nn.ConvTranspose2d(2*n, n, kernel_size=2, stride=2)


        self.conv7 =  nn.Sequential(
            nn.Conv2d(2*n,n,kernel_size=3,padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU(),
            nn.Conv2d(n,n,kernel_size=3,padding=1),
            nn.BatchNorm2d(n),
            nn.ReLU()
        )

        self.conv8 = nn.Conv2d(n,output_channel,kernel_size=1)


        ### End of your code ###

    def forward(self, x):
        # Use the convolutional operators defined above to build the U-net
        # The encoder part is already done for you.
        # You need to complete the decoder part.
        # Encoder

        x = self.conv1(x)
        
        conv1_skip = x
        
        x = self.conv2(x)
        conv2_skip = x

        
        x = self.conv3(x)
        
        conv3_skip = x
     
        x = self.conv4(x)
        
        # Decoder
        ### Insert your code ###

        x = self.up1(x)
       
        
        x = self.conv5(torch.cat([conv3_skip,x],dim=1))
        x = self.up2(x)

        
        x = self.conv6(torch.cat([conv2_skip,x],dim=1))
        x = self.up3(x)
       
        
        x = self.conv7(torch.cat([conv1_skip,x],dim=1))
        x = self.conv8(x)


        ### End of your code ###
        return x

# %% [markdown]
# ## 4. Train the segmentation model.

# %%
# CUDA device
device = torch.device('mps')
# M1 macbook used
print('Device: {0}'.format(device))

# Build the model
num_class = 4
model = UNet(input_channel=1, output_channel=num_class, num_filter=16)
model = model.to(device)
params = list(model.parameters())

model_dir = 'saved_models'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# Optimizer
optimizer = optim.Adam(params, lr=1e-3)

# Segmentation loss
criterion = nn.CrossEntropyLoss()

# Datasets
train_set = BrainImageSet('Task01_BrainTumour_2D/training_images', 'Task01_BrainTumour_2D/training_labels')
test_set = BrainImageSet('Task01_BrainTumour_2D/test_images', 'Task01_BrainTumour_2D/test_labels')

# Train the model
# Note: when you debug the model, you may reduce the number of iterations or batch size to save time.
num_iter = 10000
# num_iter = 10

train_batch_size = 16
eval_batch_size = 16
start = time.time()
for it in range(1, 1 + num_iter):
    # Set the modules in training mode, which will have effects on certain modules, e.g. dropout or batchnorm.
    start_iter = time.time()
    model.train()

    # Get a batch of images and labels
    images, labels = train_set.get_random_batch(train_batch_size)
    images, labels = torch.from_numpy(images), torch.from_numpy(labels)
    images, labels = images.to(device, dtype=torch.float32), labels.to(device, dtype=torch.long)

    
    logits = model(images)
 
    # Perform optimisation and print out the training loss
    ### Insert your code ###
    optimizer.zero_grad()
    loss = criterion(logits,labels)
    print(loss)
    loss.backward()
    optimizer.step()
    ### End of your code ###

    # Evaluate
    if it % 100 == 0:
        model.eval()
        # Disabling gradient calculation during reference to reduce memory consumption
        with torch.no_grad():
            # Evaluate on a batch of test images and print out the test loss
            ### Insert your code ###
            images, labels = test_set.get_random_batch(train_batch_size)
            images, labels = torch.from_numpy(images), torch.from_numpy(labels)
            images, labels = images.to(device, dtype=torch.float32), labels.to(device, dtype=torch.long)
            logits = model(images)
            loss = criterion(logits,labels)
            print(f'loss is {loss}')
            ### End of your code ###

    # Save the model
    if it % 5000 == 0:
        torch.save(model.state_dict(), os.path.join(model_dir, 'model_{0}.pt'.format(it)))
print('Training took {:.3f}s in total.'.format(time.time() - start))
# Out:
# tensor(0.0305, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0245, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0223, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0170, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0295, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0148, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0453, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0328, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0270, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0358, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0368, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0437, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0269, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0229, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0240, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0220, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0259, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0240, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0216, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0265, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0332, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0329, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0226, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0220, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0359, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0265, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0305, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0265, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0309, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0271, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0376, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0248, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0265, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0162, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0262, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0345, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0134, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0431, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0304, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0292, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0176, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0267, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0303, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0243, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0283, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0354, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0272, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0313, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0336, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0315, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0313, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0183, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0293, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0324, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0171, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0264, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0268, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0148, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0416, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0371, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0438, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0256, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0366, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0314, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0354, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0311, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0219, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0349, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0473, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0289, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# loss is 0.06781338900327682
# tensor(0.0236, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0224, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0250, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0225, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0244, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0178, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0373, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0204, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0262, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0284, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0281, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0393, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0214, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0270, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0235, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0245, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0280, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0229, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0196, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0359, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0344, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0203, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0180, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0390, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0307, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0350, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0405, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0334, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0297, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0247, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0288, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0305, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0248, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0275, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0229, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0294, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0371, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0284, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0320, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0260, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0166, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0310, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0379, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0258, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0227, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0151, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0269, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0181, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0354, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0293, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0277, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0397, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0168, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0284, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0327, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0254, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0474, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0229, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0213, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0343, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0285, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0288, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0266, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0209, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0355, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0178, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0336, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0380, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0234, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0326, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0291, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0356, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0190, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0220, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0206, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0214, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0417, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0254, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0254, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0137, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0161, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0498, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0347, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0255, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0221, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0236, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0230, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0273, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0368, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0269, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0294, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0220, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0251, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0292, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0197, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0387, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0177, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0303, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0188, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0303, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# loss is 0.0416179783642292
# tensor(0.0245, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0215, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0312, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0309, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.
device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0047, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0113, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0076, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0104, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0064, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0089, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0058, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0053, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0071, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0101, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0080, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0071, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0067, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0104, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0076, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0065, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0081, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0063, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0081, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0094, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0044, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0100, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0102, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0107, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0092, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0085, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0098, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0063, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0142, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0069, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# loss is 0.06465546041727066
# tensor(0.0095, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0046, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0095, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0106, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0106, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0064, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0093, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0114, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0061, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0094, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0084, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0101, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0062, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0106, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0070, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0080, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0129, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0101, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0059, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0083, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0124, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0067, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0133, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0119, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0096, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0073, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0089, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0121, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0081, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0087, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0070, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0103, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0101, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0103, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0092, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0115, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0064, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0078, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0082, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0093, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0094, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0081, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0097, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0109, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0077, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0057, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0107, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0110, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0073, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0112, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0083, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0081, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0082, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0072, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0100, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0122, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0093, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0086, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0097, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0070, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0096, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0073, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0095, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0065, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0070, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0089, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0098, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0101, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0147, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0071, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0085, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0099, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0079, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0108, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0095, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0059, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0061, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0082, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0185, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0115, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0089, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0146, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0091, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0122, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0087, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0111, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0116, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0110, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0083, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0081, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0099, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0080, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0102, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0108, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0106, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0082, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0093, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0068, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0123, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# tensor(0.0091, device='mps:0', grad_fn=<NllLoss2DBackward0>)
# loss is 0.06332913041114807
# Training took 622.209s in total.

# %% [markdown]
# ## 5. Deploy the trained model to a random set of 4 test images and visualise the automated segmentation.
#
# You can show the images as a 4 x 3 panel. Each row shows one example, with the 3 columns being the test image, automated segmentation and ground truth segmentation.

# %%
### Insert your code ###
model_path = "saved_models/model_10000.pt"
test_model = UNet(input_channel=1, output_channel=4, num_filter=16)
checkpoint = torch.load(model_path, map_location=device)
test_model.load_state_dict(checkpoint)
test_model.to(device)
test_model.eval()
images, labels = test_set.get_random_batch(4)
images, labels = torch.from_numpy(images).to(device, dtype=torch.float32), torch.from_numpy(labels).to(device, dtype=torch.long)
logits = test_model(images)
loss = criterion(logits, labels)
# print(f'type: {type(logits)}, {logits.shape}')

print(logits[0].shape)
print(labels.shape)
print(images.shape)
images = images.cpu()
images=np.reshape(images, (images.shape[0], images.shape[2], images.shape[3]))
logits=logits.cpu()
logits = logits.detach().numpy()
labels = labels.cpu()
# Output of CNN has shape NxCxHxW where N = batch size C = Number of classes and so on ∴ we need to iterate though each image in the batch and sum all the classes to form 1 image

for i in range(4):
    plt.subplot(1, 3, 1)
    plt.title('Test Image')
    plt.imshow(images[i],cmap='gray')
    plt.subplot(1, 3, 2)
    plt.title('Ground Truth segmentation')
    plt.imshow(labels[i],cmap = colors.ListedColormap(['black', 'green', 'blue', 'red']))
    plt.subplot(1, 3, 3)
    plt.title('Automated Segmentation Chosen')
    plt.imshow(np.argmax(logits[i],axis=0),cmap = colors.ListedColormap(['black', 'green', 'blue', 'red']))
    plt.gcf().set_size_inches(12, 4)
    
    plt.show()
print(f'loss is {loss}')

### End of your code ###

### End of your code ###
# Out:
# torch.Size([4, 120, 120])
# torch.Size([4, 120, 120])
# torch.Size([4, 1, 120, 120])
# loss is 0.036289017647504807

# %% [markdown]
# ## 6. Discussion. Does your trained model work well? How would you improve this model so it can be deployed to the real clinic?
